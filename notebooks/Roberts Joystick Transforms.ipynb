# %%
import pandas as pd
import numpy as np
import json
import math
import matplotlib.pyplot as plt
import subprocess
# %matplotlib notebook

# %%
df = pd.read_csv("roberts_outputs.csv")

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
